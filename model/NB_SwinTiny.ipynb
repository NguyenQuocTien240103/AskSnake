# %%
import os
import shutil
import random

# Thư mục gốc dataset
root_dir = "/kaggle/input/snakevn/VietNam_Snake_DataLast"
output_dir = "/kaggle/working/data"  # nơi lưu sau khi chia

# Tỉ lệ chia
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Tạo thư mục output
for split in ["train", "val", "test"]:
    split_dir = os.path.join(output_dir, split)
    os.makedirs(split_dir, exist_ok=True)

# Hàm lấy toàn bộ ảnh trong class (kể cả folder con)
def get_all_images_in_class(class_dir):
    image_files = []
    for root, dirs, files in os.walk(class_dir):
        for f in files:
            if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                image_files.append(os.path.join(root, f))
    return image_files

# Lặp qua từng class folder
for class_name in os.listdir(root_dir):
    class_dir = os.path.join(root_dir, class_name)
    if not os.path.isdir(class_dir):
        continue

    images = get_all_images_in_class(class_dir)

    if len(images) == 0:
        print(f"⚠️ Class {class_name} không có ảnh, bỏ qua.")
        continue

    random.shuffle(images)

    n_total = len(images)
    n_train = int(train_ratio * n_total)
    n_val = int(val_ratio * n_total)
    n_test = n_total - n_train - n_val

    train_files = images[:n_train]
    val_files = images[n_train:n_train+n_val]
    test_files = images[n_train+n_val:]

    for split, split_files in zip(["train", "val", "test"], [train_files, val_files, test_files]):
        split_class_dir = os.path.join(output_dir, split, class_name)
        os.makedirs(split_class_dir, exist_ok=True)
        for src in split_files:
            dst = os.path.join(split_class_dir, os.path.basename(src))
            shutil.copy2(src, dst)

print("✅ Done! Dataset đã được chia vào thư mục '/kaggle/working/data/train', 'val', 'test'")
# Out:
# ✅ Done! Dataset đã được chia vào thư mục '/kaggle/working/data/train', 'val', 'test'

# %%
import os
import hashlib
from collections import defaultdict

# Thư mục dataset
data_root = "/kaggle/working/data"

def file_hash(path):
    h = hashlib.md5()
    with open(path, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            h.update(chunk)
    return h.hexdigest()

# 1. Tạo hash cho train
train_hashes = {}
for root, dirs, files in os.walk(os.path.join(data_root, "train")):
    for f in files:
        if f.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            path = os.path.join(root, f)
            h = file_hash(path)
            train_hashes[h] = path  # chỉ giữ 1 path đại diện trong train

# 2. So sánh val/test với train
leak_dict = defaultdict(list)
for split in ["val", "test"]:
    split_dir = os.path.join(data_root, split)
    for root, dirs, files in os.walk(split_dir):
        for f in files:
            if f.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                path = os.path.join(root, f)
                h = file_hash(path)
                if h in train_hashes:  # nếu hash trùng với ảnh train
                    leak_dict[h].append((train_hashes[h], path))

# 3. Báo cáo leak
print(f"🔎 Tổng số nhóm leak (val/test vs train): {len(leak_dict)}\n")

for h, pairs in leak_dict.items():
    print(f"--- Hash: {h} ---")
    for p in pairs:
        print(f"Train: {p[0]}")
        print(f"Leak : {p[1]}")
        print()

# 4. Xoá ảnh leak trong val/test
delete_count = 0
for h, pairs in leak_dict.items():
    for train_path, leak_path in pairs:
        try:
            os.remove(leak_path)
            delete_count += 1
            print(f"🗑️ Deleted leak: {leak_path}")
        except Exception as e:
            print(f"❌ Error deleting {leak_path}: {e}")

print(f"\n✅ Đã xoá {delete_count} ảnh leak khỏi val/test.\n")

# 5. Check lại sau khi xoá
leak_dict_check = defaultdict(list)
for split in ["val", "test"]:
    split_dir = os.path.join(data_root, split)
    for root, dirs, files in os.walk(split_dir):
        for f in files:
            if f.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                path = os.path.join(root, f)
                h = file_hash(path)
                if h in train_hashes:
                    leak_dict_check[h].append((train_hashes[h], path))

print(f"🔎 Sau khi xoá, số nhóm leak còn lại: {len(leak_dict_check)}")
# Out:
# 🔎 Tổng số nhóm leak (val/test vs train): 61
#
# --- Hash: 438c578e035b4d552d6b08c9ce3b5a4a ---
# Train: /kaggle/working/data/train/Oreocryptophis_porphyraceus/150486480_0.jpg
# Leak : /kaggle/working/data/val/Oreocryptophis_porphyraceus/152250035_0.jpg
#
# --- Hash: e50467872b4c20378a829353a6962e18 ---
# Train: /kaggle/working/data/train/Bungarus_fasciatus/274548348_0.jpg
# Leak : /kaggle/working/data/val/Bungarus_fasciatus/276906461_0.jpg
#
# --- Hash: 2db9c856bdba07961a1e4426a13c5547 ---
# Train: /kaggle/working/data/train/Lycodon_ruhstrati/224712234_12.jpg
# Leak : /kaggle/working/data/val/Lycodon_ruhstrati/218408143_12.jpg
#
# --- Hash: 11a3b89d006b425b022858b6eff0c62f ---
# Train: /kaggle/working/data/train/Pareas_carinatus/290649718_1.jpg
# Leak : /kaggle/working/data/val/Pareas_berdmorei/290649718_1.jpg
#
# --- Hash: ef3151a13a30c41b5157c4a87e9c2895 ---
# Train: /kaggle/working/data/train/Pareas_carinatus/160903201_2.jpg
# Leak : /kaggle/working/data/val/Pareas_berdmorei/160903201_2.jpg
#
# --- Hash: 28038c0dbb8cd43fa7148b42b722bea5 ---
# Train: /kaggle/working/data/train/Laticauda_colubrina/303425602_1.jpg
# Leak : /kaggle/working/data/val/Laticauda_colubrina/303425602_0.jpg
#
# --- Hash: f91933d82c8b01521133207568436c53 ---
# Train: /kaggle/working/data/train/Elaphe_carinata/216719038_1.jpg
# Leak : /kaggle/working/data/val/Elaphe_carinata/216719038_0.jpg
#
# --- Hash: 9f99f714eb5ae39a1ae4eb2268566e58 ---
# Train: /kaggle/working/data/train/Elaphe_carinata/274559494_03.jpg
# Leak : /kaggle/working/data/val/Elaphe_carinata/274522996_03.jpg
#
# --- Hash: d63a3e4e5ea6d23ad255c2f68c8833a3 ---
# Train: /kaggle/working/data/train/Calliophis_maculiceps/145415230_12.jpg
# Leak : /kaggle/working/data/val/Calliophis_maculiceps/312381460_12.jpg
#
# --- Hash: f758fbaa5c1bab6680f576e7903561cb ---
# Train: /kaggle/working/data/train/Calliophis_maculiceps/145415230_3.jpg
# Leak : /kaggle/working/data/val/Calliophis_maculiceps/312381460_3.jpg
#
# --- Hash: 9762311fa367ef79d051c40c07816c4a ---
# Train: /kaggle/working/data/train/Pareas_berdmorei/290649718_5.jpg
# Leak : /kaggle/working/data/val/Pareas_carinatus/290649718_5.jpg
#
# --- Hash: 9ace08d348ea0e637b925e9f3d10fde9 ---
# Train: /kaggle/working/data/train/Pareas_berdmorei/160903201_0.jpg
# Leak : /kaggle/working/data/val/Pareas_carinatus/160903201_0.jpg
#
# --- Hash: fe53ad14373c347ba6f078f76a2fc47c ---
# Train: /kaggle/working/data/train/Boiga_multomaculata/280963930_0.jpg
# Leak : /kaggle/working/data/val/Boiga_multomaculata/252223036_0.jpg
#
# --- Hash: b984d9c48040643a9c3c4dbad7f0b92e ---
# Train: /kaggle/working/data/train/Plagiopholis_nuchalis/298935710_4.jpg
# Leak : /kaggle/working/data/val/Plagiopholis_nuchalis/298935710_0.jpg
#
# --- Hash: b6a6fbea3855b99bc25c3c9dae0af520 ---
# Train: /kaggle/working/data/train/Dendrelaphis_proarchos/64028671_2.jpg
# Leak : /kaggle/working/data/val/Dendrelaphis_proarchos/64028671_4.jpg
#
# --- Hash: 1b732cdc4b44f42388aafbfb1e3ede48 ---
# Train: /kaggle/working/data/train/Dendrelaphis_proarchos/64028671_0.jpg
# Leak : /kaggle/working/data/val/Dendrelaphis_proarchos/64028671_6.jpg
#
# --- Hash: 0107a99008623fc1f6d19420c90ad6fe ---
# Train: /kaggle/working/data/train/Lycodon_neomaculatus/250245653_0.jpg
# Leak : /kaggle/working/data/val/Lycodon_neomaculatus/250246316_3.jpg
#
# --- Hash: c4b5e48b0c7864222ddb9855e21f3be0 ---
# Train: /kaggle/working/data/train/Rhabdophis_subminiatus/264506701_0.jpg
# Leak : /kaggle/working/data/val/Rhabdophis_helleri/264506701_0.jpg
#
# --- Hash: ebbc21df083780a8b5c9a37b46588680 ---
# Train: /kaggle/working/data/train/Checkered_keelback/310167261_5.jpg
# Leak : /kaggle/working/data/val/Checkered_keelback/310490718_5.jpg
#
# --- Hash: 2c8d9953bd6e04d4ec1d19c75c3e314b ---
# Train: /kaggle/working/data/train/Checkered_keelback/293060169_1.jpg
# Leak : /kaggle/working/data/val/Checkered_keelback/293060169_0.jpg
#
# --- Hash: 68c05500265dcc77289db56d981e96b8 ---
# Train: /kaggle/working/data/train/Checkered_keelback/310167261_2.jpg
# Leak : /kaggle/working/data/val/Checkered_keelback/310490718_2.jpg
#
# --- Hash: 380f113b16304eba09afb8c7a3857fba ---
# Train: /kaggle/working/data/train/Checkered_keelback/310490718_33.jpg
# Leak : /kaggle/working/data/val/Checkered_keelback/310167261_33.jpg
#
# --- Hash: 991b93110cbe4367a7538efa4ca5f57c ---
# Train: /kaggle/working/data/train/Amphiesma_stolatum/245676187_02.jpg
# Leak : /kaggle/working/data/val/Amphiesma_stolatum/245852748_02.jpg
#
# --- Hash: 10ef8ca5048b34b12794eda6221fa9bf ---
# Train: /kaggle/working/data/train/Ophiophagus_hannah/139870009_2.jpg
# Leak : /kaggle/working/data/val/Ophiophagus_hannah/139870009_0.jpg
#
# --- Hash: f9495480c3b2aaa0b01f5deddcc5f762 ---
# Train: /kaggle/working/data/train/Gonyosoma_frenatum/284519354_0.jpg
# Leak : /kaggle/working/data/val/Chrysopelea_ornata/284519354_0.jpg
#
# --- Hash: 1ecc6f5ff4f69967fe9e8dd7131cafea ---
# Train: /kaggle/working/data/train/Gonyosoma_frenatum/284519354_02.jpg
# Leak : /kaggle/working/data/val/Chrysopelea_ornata/284519354_02.jpg
#
# --- Hash: 9515ca54b99a7b8ae42fafc7bc1bd1de ---
# Train: /kaggle/working/data/train/Ptyas_major/304734912_1.jpg
# Leak : /kaggle/working/data/val/Ptyas_major/304734912_6.jpg
#
# --- Hash: 2a7e61976c62243ae63da5fa26bf4992 ---
# Train: /kaggle/working/data/train/Pareas_margaritophorus/238776664_0.jpg
# Leak : /kaggle/working/data/val/Pareas_margaritophorus/212509429_7.jpg
#
# --- Hash: 4597453aa8273edec4035deccdfa36a8 ---
# Train: /kaggle/working/data/train/Pareas_margaritophorus/174817469_0.jpg
# Leak : /kaggle/working/data/val/Pareas_margaritophorus/164547777_0.jpg
#
# --- Hash: 4e7616cd5a394050e8069dfd4ddd35d3 ---
# Train: /kaggle/working/data/train/Calloselasma_rhodostoma/277286389_12.jpg
# Leak : /kaggle/working/data/val/Calloselasma_rhodostoma/277286575_12.jpg
#
# --- Hash: 05d49fd609a2896b5fdec3ac3521765f ---
# Train: /kaggle/working/data/train/Lycodon_futsingensis/172870329_2.jpg
# Leak : /kaggle/working/data/val/Lycodon_futsingensis/172954002_0.jpg
#
# --- Hash: cccdc13214e1696967006555dc4753ec ---
# Train: /kaggle/working/data/train/Lycodon_futsingensis/172870329_42.jpg
# Leak : /kaggle/working/data/val/Lycodon_futsingensis/172954002_22.jpg
#
# --- Hash: ed1260fdd51fb14b1a29cef41d7fdf4b ---
# Train: /kaggle/working/data/train/Myrrophis_chinensis/69144924_3.jpg
# Leak : /kaggle/working/data/val/Myrrophis_chinensis/69144924_1.jpg
#
# --- Hash: 6c012bfc1603eb804091ff7bc50f8da6 ---
# Train: /kaggle/working/data/train/Bungarus_fasciatus/129922834_0.jpg
# Leak : /kaggle/working/data/val/Myrrophis_chinensis/129924526_0.jpg
#
# --- Hash: 81dfb8bff9030e68ba945b57c29bf66a ---
# Train: /kaggle/working/data/train/Sinomicrurus_annularis/179110940_0.jpg
# Leak : /kaggle/working/data/val/Sinomicrurus_annularis/247449670_0.jpg
#
# --- Hash: 0d8dd9fbd698873c35d06c8ebd159d5a ---
# Train: /kaggle/working/data/train/Chrysopelea_ornata/287328948_0.jpg
# Leak : /kaggle/working/data/val/Gonyosoma_frenatum/287328948_0.jpg
#
# --- Hash: b668ca42987e83595a0094a944712937 ---
# Train: /kaggle/working/data/train/Chrysopelea_ornata/287539346_02.jpg
# Leak : /kaggle/working/data/val/Gonyosoma_frenatum/287539346_02.jpg
#
# --- Hash: b4cb694e20d212b1758b991a55140e4c ---
# Train: /kaggle/working/data/train/Cerberus_schneiderii/232690705_0.jpg
# Leak : /kaggle/working/data/val/Cerberus_schneiderii/232166724_0.jpg
#
# --- Hash: 58ed91f7729aeea47154608bfd8ac584 ---
# Train: /kaggle/working/data/train/Ptyas_korros/228824152_5.jpg
# Leak : /kaggle/working/data/val/Ptyas_korros/228824152_0.jpg
#
# --- Hash: 268a48751b2fe30ce00bcc192e839615 ---
# Train: /kaggle/working/data/train/Ptyas_korros/231955692_0.jpg
# Leak : /kaggle/working/data/val/Ptyas_korros/232170535_0.jpg
#
# --- Hash: 182aec5e051d30c55862973e61a8ddb4 ---
# Train: /kaggle/working/data/train/Oreocryptophis_porphyraceus/224708016_0.jpg
# Leak : /kaggle/working/data/test/Oreocryptophis_porphyraceus/224227413_0.jpg
#
# --- Hash: 19e6a331d95cd6e5c4f4cec3a0964262 ---
# Train: /kaggle/working/data/train/Xenopeltis_unicolor/217244009_0.jpg
# Leak : /kaggle/working/data/test/Xenopeltis_unicolor/216319143_0.jpg
#
# --- Hash: 749428ce1ffba680c2c8a86d3b2c830b ---
# Train: /kaggle/working/data/train/Acrochordus_granulatus/311445969_0.jpg
# Leak : /kaggle/working/data/test/Acrochordus_granulatus/311445969_1.jpg
#
# --- Hash: 5079bdeacad9e461caddef3364204f73 ---
# Train: /kaggle/working/data/train/Oligodon_albocinctus/163640937_8.jpg
# Leak : /kaggle/working/data/test/Oligodon_albocinctus/163640937_0.jpg
#
# --- Hash: 9a4bc48f34d5423cad361b1ef38f4dd8 ---
# Train: /kaggle/working/data/train/Calliophis_maculiceps/145415230_1.jpg
# Leak : /kaggle/working/data/test/Calliophis_maculiceps/312381460_1.jpg
#
# --- Hash: 1702ac78ec375666dc192c4736190d5d ---
# Train: /kaggle/working/data/train/Pareas_carinatus/266897722_0.jpg
# Leak : /kaggle/working/data/test/Pareas_carinatus/266893764_0.jpg
#
# --- Hash: 929eab1306c0fdfaebb59329166608f7 ---
# Train: /kaggle/working/data/train/Pareas_berdmorei/160903201_22.jpg
# Leak : /kaggle/working/data/test/Pareas_carinatus/160903201_22.jpg
#
# --- Hash: a6d20347ddace8baa8a75b35b0d18b70 ---
# Train: /kaggle/working/data/train/Lycodon_truongi/214112145_1.jpg
# Leak : /kaggle/working/data/test/Lycodon_truongi/214112145_0.jpg
#
# --- Hash: 18ae065d190c75d4c3794e98cb442fda ---
# Train: /kaggle/working/data/train/Rhabdophis_helleri/250684996_0.jpg
# Leak : /kaggle/working/data/test/Rhabdophis_subminiatus/250684996_0.jpg
#
# --- Hash: 1fb54d63e00076733fed33940be4e379 ---
# Train: /kaggle/working/data/train/Coelognathus_radiatus/247880021_2.jpg
# Leak : /kaggle/working/data/test/Coelognathus_radiatus/247880021_0.jpg
#
# --- Hash: b05cdcdc31ee72474519ffb127655caf ---
# Train: /kaggle/working/data/train/Pareas_margaritophorus/223132436_02.jpg
# Leak : /kaggle/working/data/test/Pareas_margaritophorus/223132436_02_1.jpg
#
# --- Hash: 854efa5d6992cab05b85d753883e9408 ---
# Train: /kaggle/working/data/train/Lycodon_davisonii/176923057_0.jpg
# Leak : /kaggle/working/data/test/Lycodon_davisonii/176925976_0.jpg
#
# --- Hash: 5ae114781989c80f0d1b933c2e4a26be ---
# Train: /kaggle/working/data/train/Calloselasma_rhodostoma/277286389_1.jpg
# Leak : /kaggle/working/data/test/Calloselasma_rhodostoma/277286575_1.jpg
#
# --- Hash: f7b103aadd47f64569f31996d1dc4e75 ---
# Train: /kaggle/working/data/train/Lycodon_futsingensis/172953916_5.jpg
# Leak : /kaggle/working/data/test/Lycodon_futsingensis/172870811_2.jpg
#
# --- Hash: e0545c9b117a735390e6867f1bc4c0db ---
# Train: /kaggle/working/data/train/Myrrophis_chinensis/134960669_0.jpg
# Leak : /kaggle/working/data/test/Myrrophis_chinensis/152713520_0.jpg
#
# --- Hash: 8960fb4b4225e6bff0906ef6b15e9e38 ---
# Train: /kaggle/working/data/train/Python_bivittatus/292837265_1.jpg
# Leak : /kaggle/working/data/test/Python_bivittatus/291688390_3.jpg
#
# --- Hash: 6189a7d41045d92386210ce250754f0a ---
# Train: /kaggle/working/data/train/Python_bivittatus/292837265_0.jpg
# Leak : /kaggle/working/data/test/Python_bivittatus/291688390_2.jpg
#
# --- Hash: 6636c51b880be85bd94ea6f3625ae13b ---
# Train: /kaggle/working/data/train/Sinomicrurus_peinani/179113453_02.jpg
# Leak : /kaggle/working/data/test/Sinomicrurus_annularis/247449513_02.jpg
#
# --- Hash: 5299983bfce6bd8223835ad96c82d9c7 ---
# Train: /kaggle/working/data/train/Blue-lipped_sea_krait/132025696_0.jpg
# Leak : /kaggle/working/data/test/Blue-lipped_sea_krait/180718293_0.jpg
#
# --- Hash: a517b2f1f1e5121b43d7a80204da2ce7 ---
# Train: /kaggle/working/data/train/Cerberus_schneiderii/253616931_0.jpg
# Leak : /kaggle/working/data/test/Cerberus_schneiderii/250440344_0.jpg
#
# --- Hash: 2500347381f98330db1d225b5acfa5e5 ---
# Train: /kaggle/working/data/train/Ptyas_korros/231955692_02.jpg
# Leak : /kaggle/working/data/test/Ptyas_korros/232170535_02.jpg
#
# 🗑️ Deleted leak: /kaggle/working/data/val/Oreocryptophis_porphyraceus/152250035_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Bungarus_fasciatus/276906461_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Lycodon_ruhstrati/218408143_12.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_berdmorei/290649718_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_berdmorei/160903201_2.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Laticauda_colubrina/303425602_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Elaphe_carinata/216719038_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Elaphe_carinata/274522996_03.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Calliophis_maculiceps/312381460_12.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Calliophis_maculiceps/312381460_3.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_carinatus/290649718_5.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_carinatus/160903201_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Boiga_multomaculata/252223036_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Plagiopholis_nuchalis/298935710_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Dendrelaphis_proarchos/64028671_4.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Dendrelaphis_proarchos/64028671_6.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Lycodon_neomaculatus/250246316_3.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Rhabdophis_helleri/264506701_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Checkered_keelback/310490718_5.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Checkered_keelback/293060169_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Checkered_keelback/310490718_2.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Checkered_keelback/310167261_33.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Amphiesma_stolatum/245852748_02.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Ophiophagus_hannah/139870009_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Chrysopelea_ornata/284519354_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Chrysopelea_ornata/284519354_02.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Ptyas_major/304734912_6.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_margaritophorus/212509429_7.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Pareas_margaritophorus/164547777_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Calloselasma_rhodostoma/277286575_12.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Lycodon_futsingensis/172954002_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Lycodon_futsingensis/172954002_22.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Myrrophis_chinensis/69144924_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Myrrophis_chinensis/129924526_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Sinomicrurus_annularis/247449670_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Gonyosoma_frenatum/287328948_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Gonyosoma_frenatum/287539346_02.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Cerberus_schneiderii/232166724_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Ptyas_korros/228824152_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/val/Ptyas_korros/232170535_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Oreocryptophis_porphyraceus/224227413_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Xenopeltis_unicolor/216319143_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Acrochordus_granulatus/311445969_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Oligodon_albocinctus/163640937_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Calliophis_maculiceps/312381460_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Pareas_carinatus/266893764_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Pareas_carinatus/160903201_22.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Lycodon_truongi/214112145_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Rhabdophis_subminiatus/250684996_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Coelognathus_radiatus/247880021_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Pareas_margaritophorus/223132436_02_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Lycodon_davisonii/176925976_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Calloselasma_rhodostoma/277286575_1.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Lycodon_futsingensis/172870811_2.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Myrrophis_chinensis/152713520_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Python_bivittatus/291688390_3.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Python_bivittatus/291688390_2.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Sinomicrurus_annularis/247449513_02.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Blue-lipped_sea_krait/180718293_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Cerberus_schneiderii/250440344_0.jpg
# 🗑️ Deleted leak: /kaggle/working/data/test/Ptyas_korros/232170535_02.jpg
#
# ✅ Đã xoá 61 ảnh leak khỏi val/test.
#
# 🔎 Sau khi xoá, số nhóm leak còn lại: 0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import time
import copy
import os

# =========================
# 1. Config
# =========================
data_dir = "/kaggle/working/data"   # Cấu trúc thư mục: data/train, data/val
num_classes = 124
batch_size = 32
num_epochs = 30
lr = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================
# 2. Data Augmentation
# =========================
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])


image_datasets = {
    'train': datasets.ImageFolder(os.path.join(data_dir, 'train'), train_transform),
    'val': datasets.ImageFolder(os.path.join(data_dir, 'val'), val_transform)
}

dataloaders = {
    x: DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4)
    for x in ['train', 'val']
}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

# =========================
# 3. Model
# =========================
model = models.swin_t(weights="IMAGENET1K_V1")  # pretrained Swin-Tiny
model.head = nn.Linear(model.head.in_features, num_classes)
model = model.to(device)

# =========================
# 4. Loss, Optimizer, Scheduler
# =========================
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

# =========================
# 5. Training Loop
# =========================
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    # Thêm history để vẽ sau này
    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": []
    }
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 20)
        
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            
            running_loss = 0.0
            running_corrects = 0
            
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double().item() / dataset_sizes[phase]
            
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            
            # Lưu history
            history[f"{phase}_loss"].append(epoch_loss)
            history[f"{phase}_acc"].append(epoch_acc)
            
            # Save best
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
        
        # ================================
        # 🔹 Lưu model sau mỗi 5 epoch
        # ================================
        if (epoch + 1) % 5 == 0:
            save_path = f"/kaggle/working/swin_tiny_epoch{epoch+1}.pth"
            torch.save(model.state_dict(), save_path)
            print(f"✅ Saved model at {save_path}")
        
        print()
    
    print(f'Best val Acc: {best_acc:.4f}')
    model.load_state_dict(best_model_wts)
    return model, history

# =========================
# 6. Run Training
# =========================
model, history = train_model(model, criterion, optimizer, scheduler, num_epochs=num_epochs)

# Save final best model
torch.save(model.state_dict(), "/kaggle/working/swin_tiny_best.pth")
# Out:
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100%|██████████| 108M/108M [00:00<00:00, 175MB/s]
# Epoch 1/30
# --------------------
# train Loss: 2.6701 Acc: 0.4704
# val Loss: 1.7186 Acc: 0.7126
#
# Epoch 2/30
# --------------------
# train Loss: 1.8725 Acc: 0.6852
# val Loss: 1.4697 Acc: 0.7991
#
# Epoch 3/30
# --------------------
# train Loss: 1.6699 Acc: 0.7490
# val Loss: 1.4266 Acc: 0.8112
#
# Epoch 4/30
# --------------------
# train Loss: 1.5599 Acc: 0.7827
# val Loss: 1.3455 Acc: 0.8379
#
# Epoch 5/30
# --------------------
# train Loss: 1.4630 Acc: 0.8142
# val Loss: 1.2852 Acc: 0.8548
# ✅ Saved model at /kaggle/working/swin_tiny_epoch5.pth
#
# Epoch 6/30
# --------------------
# train Loss: 1.4160 Acc: 0.8265
# val Loss: 1.2460 Acc: 0.8727
#
# Epoch 7/30
# --------------------
# train Loss: 1.3767 Acc: 0.8397
# val Loss: 1.2574 Acc: 0.8656
#
# Epoch 8/30
# --------------------
# train Loss: 1.3101 Acc: 0.8598
# val Loss: 1.2174 Acc: 0.8767
#
# Epoch 9/30
# --------------------
# train Loss: 1.2852 Acc: 0.8689
# val Loss: 1.1929 Acc: 0.8899
#
# Epoch 10/30
# --------------------
# train Loss: 1.2617 Acc: 0.8726
# val Loss: 1.1794 Acc: 0.8923
# ✅ Saved model at /kaggle/working/swin_tiny_epoch10.pth
#
# Epoch 11/30
# --------------------
# train Loss: 1.2258 Acc: 0.8875
# val Loss: 1.1697 Acc: 0.8859
#
# Epoch 12/30
# --------------------
# train Loss: 1.1957 Acc: 0.8977
# val Loss: 1.1610 Acc: 0.8896
#
# Epoch 13/30
# --------------------
# train Loss: 1.1727 Acc: 0.9043
# val Loss: 1.1781 Acc: 0.8883
#
# Epoch 14/30
# --------------------
# train Loss: 1.1596 Acc: 0.9052
# val Loss: 1.1225 Acc: 0.9086
#
# Epoch 15/30
# --------------------
# train Loss: 1.1345 Acc: 0.9157
# val Loss: 1.1233 Acc: 0.9011
# ✅ Saved model at /kaggle/working/swin_tiny_epoch15.pth
#
# Epoch 16/30
# --------------------
# train Loss: 1.1156 Acc: 0.9201
# val Loss: 1.1092 Acc: 0.9093
#
# Epoch 17/30
# --------------------
# train Loss: 1.0920 Acc: 0.9293
# val Loss: 1.1206 Acc: 0.9055
#
# Epoch 18/30
# --------------------
# train Loss: 1.0828 Acc: 0.9325
# val Loss: 1.0965 Acc: 0.9128
#
# Epoch 19/30
# --------------------
# train Loss: 1.0795 Acc: 0.9314
# val Loss: 1.1140 Acc: 0.9064
#
# Epoch 20/30
# --------------------
# train Loss: 1.0542 Acc: 0.9400
# val Loss: 1.0857 Acc: 0.9178
# ✅ Saved model at /kaggle/working/swin_tiny_epoch20.pth
#
# Epoch 21/30
# --------------------
# train Loss: 1.0511 Acc: 0.9413
# val Loss: 1.0845 Acc: 0.9159
#
# Epoch 22/30
# --------------------
# train Loss: 1.0342 Acc: 0.9439
# val Loss: 1.0668 Acc: 0.9227
#
# Epoch 23/30
# --------------------
# train Loss: 1.0329 Acc: 0.9450
# val Loss: 1.0698 Acc: 0.9196
#
# Epoch 24/30
# --------------------
# train Loss: 1.0297 Acc: 0.9468
# val Loss: 1.0685 Acc: 0.9205
#
# Epoch 25/30
# --------------------
# train Loss: 1.0073 Acc: 0.9532
# val Loss: 1.0725 Acc: 0.9200
# ✅ Saved model at /kaggle/working/swin_tiny_epoch25.pth
#
# Epoch 26/30
# --------------------
# train Loss: 1.0146 Acc: 0.9500
# val Loss: 1.0691 Acc: 0.9214
#
# Epoch 27/30
# --------------------
# train Loss: 1.0042 Acc: 0.9538
# val Loss: 1.0672 Acc: 0.9196
#
# Epoch 28/30
# --------------------
# train Loss: 1.0053 Acc: 0.9538
# val Loss: 1.0651 Acc: 0.9207
#
# Epoch 29/30
# --------------------
# train Loss: 1.0042 Acc: 0.9530
# val Loss: 1.0640 Acc: 0.9216
#
# Epoch 30/30
# --------------------
# train Loss: 1.0072 Acc: 0.9531
# val Loss: 1.0639 Acc: 0.9216
# ✅ Saved model at /kaggle/working/swin_tiny_epoch30.pth
#
# Best val Acc: 0.9227

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

# =========================
# 7. Evaluation on Test Set
# =========================
# Load lại test dataset
test_dataset = datasets.ImageFolder(os.path.join(data_dir, 'test'), val_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Lấy mapping index -> class name
class_names = test_dataset.classes
num_classes = len(class_names)

# Load best model đã save
model.load_state_dict(torch.load("/kaggle/working/swin_tiny_best.pth"))
model.eval()

all_labels = []
all_preds = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

# =========================
# 8. Tính accuracy
# =========================
overall_acc = accuracy_score(all_labels, all_preds)
print(f"\nTest Accuracy: {overall_acc:.4f}")

# =========================
# 9. Accuracy từng class
# =========================
all_labels = np.array(all_labels)
all_preds = np.array(all_preds)

print("\nAccuracy theo từng class:")
for i, class_name in enumerate(class_names):
    idx = (all_labels == i)
    if np.sum(idx) == 0:
        acc = 0.0
    else:
        acc = np.mean(all_preds[idx] == all_labels[idx])
    correct = np.sum(all_preds[idx] == all_labels[idx])
    total = np.sum(idx)
    print(f"{class_name:25s}  Acc: {acc:.4f}  ({correct}/{total})")

# =========================
# 10. Classification Report (optional)
# =========================
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names, digits=4))
# Out:
# Test Accuracy: 0.9257
#
# Accuracy theo từng class:
# Achalinus_rufescens        Acc: 1.0000  (13/13)
# Achalinus_spinalis         Acc: 0.9286  (13/14)
# Acrochordus_granulatus     Acc: 0.9767  (42/43)
# Acrochordus_javanicus      Acc: 0.6250  (5/8)
# Ahaetulla_fusca            Acc: 0.8519  (23/27)
# Ahaetulla_prasina          Acc: 0.9500  (19/20)
# Ahaetulla_rufusoculara     Acc: 0.8889  (8/9)
# Amphiesma_stolatum         Acc: 0.9474  (72/76)
# Blue-lipped_sea_krait      Acc: 0.9506  (77/81)
# Boiga_cyanea               Acc: 0.9500  (76/80)
# Boiga_guangxiensis         Acc: 1.0000  (8/8)
# Boiga_jaspidea             Acc: 1.0000  (41/41)
# Boiga_kraepelini           Acc: 0.9701  (65/67)
# Boiga_multomaculata        Acc: 0.9700  (97/100)
# Boiga_siamensis            Acc: 0.9032  (28/31)
# Bungarus_candidus          Acc: 0.9859  (70/71)
# Bungarus_fasciatus         Acc: 0.9885  (86/87)
# Calamaria_septentrionalis  Acc: 0.8636  (19/22)
# Calliophis_maculiceps      Acc: 1.0000  (17/17)
# Calloselasma_rhodostoma    Acc: 0.9703  (98/101)
# Cerberus_schneiderii       Acc: 0.8780  (36/41)
# Checkered_keelback         Acc: 0.7746  (55/71)
# Chrysopelea_ornata         Acc: 1.0000  (68/68)
# Coelognathus_flavolineatus  Acc: 0.9667  (29/30)
# Coelognathus_radiatus      Acc: 0.9651  (83/86)
# Cylindrophis_jodiae        Acc: 0.8511  (40/47)
# Cylindrophis_ruffus        Acc: 0.8529  (29/34)
# Deinagkistrodon_acutus     Acc: 0.9709  (100/103)
# Dendrelaphis_ngansonensis  Acc: 0.8846  (23/26)
# Dendrelaphis_proarchos     Acc: 0.8182  (9/11)
# Dendrelaphis_subocularis   Acc: 1.0000  (20/20)
# Dryophiops_rubescens       Acc: 0.9286  (39/42)
# Elaphe_carinata            Acc: 0.9067  (68/75)
# Elaphe_moellendorffi       Acc: 0.8889  (8/9)
# Elaphe_taeniura            Acc: 0.9518  (79/83)
# Enhydris_subtaeniata       Acc: 0.9000  (9/10)
# Erpeton_tentaculatum       Acc: 0.4444  (4/9)
# Euprepiophis_mandarinus    Acc: 0.9310  (54/58)
# Fordonia_leucobalia        Acc: 1.0000  (8/8)
# Fowlea_flavipunctata       Acc: 0.8235  (28/34)
# Gonyosoma_boulengeri       Acc: 0.7143  (5/7)
# Gonyosoma_coeruleum        Acc: 0.9500  (19/20)
# Gonyosoma_frenatum         Acc: 0.6250  (5/8)
# Gonyosoma_oxycephalum      Acc: 0.7619  (16/21)
# Hebius_boulengeri          Acc: 0.9333  (14/15)
# Hebius_khasiensis          Acc: 0.8000  (4/5)
# Hebius_optatus             Acc: 0.6667  (4/6)
# Hebius_sauteri             Acc: 1.0000  (17/17)
# Homalopsis_mereljcoxi      Acc: 0.8571  (12/14)
# Hydrophis_peronii          Acc: 1.0000  (9/9)
# Hypsiscopus_murphyi        Acc: 0.9643  (54/56)
# Indotyphlops_braminus      Acc: 1.0000  (79/79)
# Kuatun_keelback            Acc: 0.9000  (18/20)
# Laticauda_colubrina        Acc: 1.0000  (82/82)
# Lycodon_capucinus          Acc: 0.9545  (84/88)
# Lycodon_chapaensis         Acc: 0.9000  (9/10)
# Lycodon_davisonii          Acc: 0.7805  (32/41)
# Lycodon_fasciatus          Acc: 0.9444  (17/18)
# Lycodon_futsingensis       Acc: 0.9344  (57/61)
# Lycodon_laoensis           Acc: 0.9583  (46/48)
# Lycodon_meridionalis       Acc: 0.8333  (15/18)
# Lycodon_neomaculatus       Acc: 0.9062  (29/32)
# Lycodon_pictus             Acc: 0.7778  (7/9)
# Lycodon_rufozonatus        Acc: 0.9750  (78/80)
# Lycodon_ruhstrati          Acc: 0.8873  (63/71)
# Lycodon_truongi            Acc: 1.0000  (7/7)
# Malayopython_reticulatus   Acc: 0.9737  (74/76)
# Myrrophis_chinensis        Acc: 0.9118  (31/34)
# Naja_atra                  Acc: 1.0000  (41/41)
# Naja_fuxi                  Acc: 0.8000  (8/10)
# Naja_siamensis             Acc: 0.7500  (9/12)
# Oligodon_albocinctus       Acc: 0.7000  (7/10)
# Oligodon_chinensis         Acc: 0.9636  (53/55)
# Oligodon_cinereus          Acc: 0.8889  (16/18)
# Oligodon_cyclurus          Acc: 0.6000  (6/10)
# Oligodon_deuvei            Acc: 0.7500  (6/8)
# Oligodon_fasciolatus       Acc: 0.7600  (19/25)
# Oligodon_formosanus        Acc: 0.9355  (29/31)
# Oligodon_taeniatus         Acc: 0.8974  (35/39)
# Ophiophagus_hannah         Acc: 0.9286  (78/84)
# Oreocryptophis_porphyraceus  Acc: 0.9870  (76/77)
# Ovophis_monticola          Acc: 0.9667  (29/30)
# Ovophis_tonkinensis        Acc: 0.9434  (50/53)
# Pareas_berdmorei           Acc: 0.7000  (21/30)
# Pareas_carinatus           Acc: 0.9180  (112/122)
# Pareas_formosensis         Acc: 0.9368  (89/95)
# Pareas_hamptoni            Acc: 0.1429  (1/7)
# Pareas_margaritophorus     Acc: 0.9675  (119/123)
# Pareas_monticola           Acc: 0.6000  (3/5)
# Plagiopholis_nuchalis      Acc: 1.0000  (8/8)
# Pope_s_keelback            Acc: 0.8000  (12/15)
# Protobothrops_cornutus     Acc: 0.9375  (15/16)
# Protobothrops_jerdonii     Acc: 0.9167  (33/36)
# Protobothrops_maolanensis  Acc: 1.0000  (23/23)
# Protobothrops_mucrosquamatus  Acc: 1.0000  (63/63)
# Psammodynastes_pulverulentus  Acc: 0.9206  (58/63)
# Pseudoxenodon_bambusicola  Acc: 1.0000  (13/13)
# Pseudoxenodon_macrops      Acc: 0.8947  (34/38)
# Ptyas_carinata             Acc: 0.7000  (7/10)
# Ptyas_dhumnades            Acc: 0.9811  (52/53)
# Ptyas_korros               Acc: 0.8913  (41/46)
# Ptyas_major                Acc: 0.9663  (86/89)
# Ptyas_mucosa               Acc: 0.8000  (12/15)
# Ptyas_multicincta          Acc: 0.8824  (15/17)
# Ptyas_nigromarginata       Acc: 0.8333  (5/6)
# Python_bivittatus          Acc: 0.9740  (75/77)
# Red-headed_krait           Acc: 0.9444  (17/18)
# Rhabdophis_chrysargos      Acc: 0.9744  (38/39)
# Rhabdophis_helleri         Acc: 0.9130  (21/23)
# Rhabdophis_nigrocinctus    Acc: 0.8182  (9/11)
# Rhabdophis_subminiatus     Acc: 0.9714  (34/35)
# Rhabdophis_tigrinus        Acc: 0.8929  (25/28)
# Sibynophis_chinensis       Acc: 0.9118  (31/34)
# Sinomicrurus_annularis     Acc: 0.8824  (30/34)
# Sinomicrurus_macclellandi  Acc: 0.7200  (18/25)
# Sinomicrurus_peinani       Acc: 0.6250  (5/8)
# Subsessor_bocourti         Acc: 0.8750  (7/8)
# Trimeresurus_albolabris    Acc: 0.6875  (11/16)
# Trimeresurus_rubeus        Acc: 0.9737  (37/38)
# Trimeresurus_stejnegeri    Acc: 0.8308  (54/65)
# Trimeresurus_vogeli        Acc: 0.9400  (47/50)
# Trimerodytes_aequifasciatus  Acc: 0.8125  (13/16)
# Trimerodytes_percarinatus  Acc: 0.8065  (25/31)
# Xenopeltis_unicolor        Acc: 0.9815  (53/54)
#
# Classification Report:
#                               precision    recall  f1-score   support
#
#          Achalinus_rufescens     0.8667    1.0000    0.9286        13
#           Achalinus_spinalis     0.9286    0.9286    0.9286        14
#       Acrochordus_granulatus     0.9333    0.9767    0.9545        43
#        Acrochordus_javanicus     1.0000    0.6250    0.7692         8
#              Ahaetulla_fusca     0.9583    0.8519    0.9020        27
#            Ahaetulla_prasina     0.9500    0.9500    0.9500        20
#       Ahaetulla_rufusoculara     1.0000    0.8889    0.9412         9
#           Amphiesma_stolatum     0.9114    0.9474    0.9290        76
#        Blue-lipped_sea_krait     1.0000    0.9506    0.9747        81
#                 Boiga_cyanea     0.9500    0.9500    0.9500        80
#           Boiga_guangxiensis     0.8889    1.0000    0.9412         8
#               Boiga_jaspidea     0.9762    1.0000    0.9880        41
#             Boiga_kraepelini     0.9028    0.9701    0.9353        67
#          Boiga_multomaculata     0.9700    0.9700    0.9700       100
#              Boiga_siamensis     0.9333    0.9032    0.9180        31
#            Bungarus_candidus     0.9333    0.9859    0.9589        71
#           Bungarus_fasciatus     1.0000    0.9885    0.9942        87
#    Calamaria_septentrionalis     0.7917    0.8636    0.8261        22
#        Calliophis_maculiceps     0.9444    1.0000    0.9714        17
#      Calloselasma_rhodostoma     0.9515    0.9703    0.9608       101
#         Cerberus_schneiderii     0.9000    0.8780    0.8889        41
#           Checkered_keelback     0.7857    0.7746    0.7801        71
#           Chrysopelea_ornata     0.9577    1.0000    0.9784        68
#   Coelognathus_flavolineatus     1.0000    0.9667    0.9831        30
#        Coelognathus_radiatus     0.9881    0.9651    0.9765        86
#          Cylindrophis_jodiae     0.8696    0.8511    0.8602        47
#          Cylindrophis_ruffus     0.8286    0.8529    0.8406        34
#       Deinagkistrodon_acutus     0.9804    0.9709    0.9756       103
#    Dendrelaphis_ngansonensis     0.9200    0.8846    0.9020        26
#       Dendrelaphis_proarchos     1.0000    0.8182    0.9000        11
#     Dendrelaphis_subocularis     0.8696    1.0000    0.9302        20
#         Dryophiops_rubescens     0.9512    0.9286    0.9398        42
#              Elaphe_carinata     0.9444    0.9067    0.9252        75
#         Elaphe_moellendorffi     1.0000    0.8889    0.9412         9
#              Elaphe_taeniura     0.9294    0.9518    0.9405        83
#         Enhydris_subtaeniata     1.0000    0.9000    0.9474        10
#         Erpeton_tentaculatum     1.0000    0.4444    0.6154         9
#      Euprepiophis_mandarinus     0.9818    0.9310    0.9558        58
#          Fordonia_leucobalia     0.8889    1.0000    0.9412         8
#         Fowlea_flavipunctata     0.8000    0.8235    0.8116        34
#         Gonyosoma_boulengeri     0.8333    0.7143    0.7692         7
#          Gonyosoma_coeruleum     0.9048    0.9500    0.9268        20
#           Gonyosoma_frenatum     0.8333    0.6250    0.7143         8
#        Gonyosoma_oxycephalum     0.8421    0.7619    0.8000        21
#            Hebius_boulengeri     1.0000    0.9333    0.9655        15
#            Hebius_khasiensis     1.0000    0.8000    0.8889         5
#               Hebius_optatus     1.0000    0.6667    0.8000         6
#               Hebius_sauteri     0.8947    1.0000    0.9444        17
#        Homalopsis_mereljcoxi     1.0000    0.8571    0.9231        14
#            Hydrophis_peronii     1.0000    1.0000    1.0000         9
#          Hypsiscopus_murphyi     0.9818    0.9643    0.9730        56
#        Indotyphlops_braminus     0.9753    1.0000    0.9875        79
#              Kuatun_keelback     0.9474    0.9000    0.9231        20
#          Laticauda_colubrina     0.9213    1.0000    0.9591        82
#            Lycodon_capucinus     0.9333    0.9545    0.9438        88
#           Lycodon_chapaensis     0.9000    0.9000    0.9000        10
#            Lycodon_davisonii     0.9412    0.7805    0.8533        41
#            Lycodon_fasciatus     0.8500    0.9444    0.8947        18
#         Lycodon_futsingensis     0.9194    0.9344    0.9268        61
#             Lycodon_laoensis     0.9787    0.9583    0.9684        48
#         Lycodon_meridionalis     1.0000    0.8333    0.9091        18
#         Lycodon_neomaculatus     0.9062    0.9062    0.9062        32
#               Lycodon_pictus     1.0000    0.7778    0.8750         9
#          Lycodon_rufozonatus     0.9512    0.9750    0.9630        80
#            Lycodon_ruhstrati     0.8630    0.8873    0.8750        71
#              Lycodon_truongi     0.8750    1.0000    0.9333         7
#     Malayopython_reticulatus     0.9737    0.9737    0.9737        76
#          Myrrophis_chinensis     0.8857    0.9118    0.8986        34
#                    Naja_atra     0.8913    1.0000    0.9425        41
#                    Naja_fuxi     0.8889    0.8000    0.8421        10
#               Naja_siamensis     0.9000    0.7500    0.8182        12
#         Oligodon_albocinctus     0.8750    0.7000    0.7778        10
#           Oligodon_chinensis     0.9636    0.9636    0.9636        55
#            Oligodon_cinereus     0.8889    0.8889    0.8889        18
#            Oligodon_cyclurus     1.0000    0.6000    0.7500        10
#              Oligodon_deuvei     0.7500    0.7500    0.7500         8
#         Oligodon_fasciolatus     0.8636    0.7600    0.8085        25
#          Oligodon_formosanus     0.8056    0.9355    0.8657        31
#           Oligodon_taeniatus     0.8974    0.8974    0.8974        39
#           Ophiophagus_hannah     0.9176    0.9286    0.9231        84
#  Oreocryptophis_porphyraceus     0.9383    0.9870    0.9620        77
#            Ovophis_monticola     0.9355    0.9667    0.9508        30
#          Ovophis_tonkinensis     0.9615    0.9434    0.9524        53
#             Pareas_berdmorei     0.9545    0.7000    0.8077        30
#             Pareas_carinatus     0.8889    0.9180    0.9032       122
#           Pareas_formosensis     0.8990    0.9368    0.9175        95
#              Pareas_hamptoni     0.1667    0.1429    0.1538         7
#       Pareas_margaritophorus     0.9444    0.9675    0.9558       123
#             Pareas_monticola     1.0000    0.6000    0.7500         5
#        Plagiopholis_nuchalis     1.0000    1.0000    1.0000         8
#              Pope_s_keelback     0.9231    0.8000    0.8571        15
#       Protobothrops_cornutus     1.0000    0.9375    0.9677        16
#       Protobothrops_jerdonii     0.9429    0.9167    0.9296        36
#    Protobothrops_maolanensis     0.9200    1.0000    0.9583        23
# Protobothrops_mucrosquamatus     0.9692    1.0000    0.9844        63
# Psammodynastes_pulverulentus     0.9508    0.9206    0.9355        63
#    Pseudoxenodon_bambusicola     0.9286    1.0000    0.9630        13
#        Pseudoxenodon_macrops     0.9444    0.8947    0.9189        38
#               Ptyas_carinata     1.0000    0.7000    0.8235        10
#              Ptyas_dhumnades     0.9455    0.9811    0.9630        53
#                 Ptyas_korros     0.8200    0.8913    0.8542        46
#                  Ptyas_major     0.8866    0.9663    0.9247        89
#                 Ptyas_mucosa     0.5714    0.8000    0.6667        15
#            Ptyas_multicincta     0.7895    0.8824    0.8333        17
#         Ptyas_nigromarginata     1.0000    0.8333    0.9091         6
#            Python_bivittatus     0.9740    0.9740    0.9740        77
#             Red-headed_krait     1.0000    0.9444    0.9714        18
#        Rhabdophis_chrysargos     0.9500    0.9744    0.9620        39
#           Rhabdophis_helleri     0.9130    0.9130    0.9130        23
#      Rhabdophis_nigrocinctus     0.9000    0.8182    0.8571        11
#       Rhabdophis_subminiatus     0.9189    0.9714    0.9444        35
#          Rhabdophis_tigrinus     0.9259    0.8929    0.9091        28
#         Sibynophis_chinensis     0.9394    0.9118    0.9254        34
#       Sinomicrurus_annularis     0.8824    0.8824    0.8824        34
#    Sinomicrurus_macclellandi     0.7826    0.7200    0.7500        25
#         Sinomicrurus_peinani     0.8333    0.6250    0.7143         8
#           Subsessor_bocourti     1.0000    0.8750    0.9333         8
#      Trimeresurus_albolabris     0.7857    0.6875    0.7333        16
#          Trimeresurus_rubeus     0.8810    0.9737    0.9250        38
#      Trimeresurus_stejnegeri     0.9000    0.8308    0.8640        65
#          Trimeresurus_vogeli     0.9216    0.9400    0.9307        50
#  Trimerodytes_aequifasciatus     0.9286    0.8125    0.8667        16
#    Trimerodytes_percarinatus     0.8929    0.8065    0.8475        31
#          Xenopeltis_unicolor     0.9636    0.9815    0.9725        54
#
#                     accuracy                         0.9257      4739
#                    macro avg     0.9170    0.8836    0.8957      4739
#                 weighted avg     0.9271    0.9257    0.9248      4739

# %%
import matplotlib.pyplot as plt

epochs = range(1, num_epochs+1)

plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(epochs, history["train_loss"], 'o-', label="Train Loss")
plt.plot(epochs, history["val_loss"], 's-', label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Val Loss")
plt.legend()
plt.grid(True)

# Accuracy
plt.subplot(1,2,2)
plt.plot(epochs, history["train_acc"], 'o-', label="Train Acc")
plt.plot(epochs, history["val_acc"], 's-', label="Val Acc")
plt.axhline(y=overall_acc, color='r', linestyle='--', label=f"Test Acc = {overall_acc:.4f}")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Val Accuracy")
plt.legend()
plt.grid(True)

plt.show()

# %%
print("\n⚠️ Các class dưới 70% accuracy:")
for i, class_name in enumerate(class_names):
    idx = (all_labels == i)
    if np.sum(idx) == 0:
        acc = 0.0
        correct, total = 0, 0
    else:
        acc = np.mean(all_preds[idx] == all_labels[idx])
        correct = np.sum(all_preds[idx] == all_labels[idx])
        total = np.sum(idx)

    if acc < 0.7:  # dưới 70%
        print(f"{class_name:25s}  Acc: {acc:.4f}  ({correct}/{total})")
# Out:
# ⚠️ Các class dưới 70% accuracy:
# Acrochordus_javanicus      Acc: 0.6250  (5/8)
# Erpeton_tentaculatum       Acc: 0.4444  (4/9)
# Gonyosoma_frenatum         Acc: 0.6250  (5/8)
# Hebius_optatus             Acc: 0.6667  (4/6)
# Oligodon_cyclurus          Acc: 0.6000  (6/10)
# Pareas_hamptoni            Acc: 0.1429  (1/7)
# Pareas_monticola           Acc: 0.6000  (3/5)
# Sinomicrurus_peinani       Acc: 0.6250  (5/8)
# Trimeresurus_albolabris    Acc: 0.6875  (11/16)

# %%
import torch
from torchvision import transforms
from PIL import Image
import requests
from io import BytesIO

# =====================
# Load model
# =====================
num_classes = 124
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Khởi tạo lại model giống lúc train
model = models.swin_t(weights=None)   # không load pretrained vì ta đã có weight rồi
model.head = nn.Linear(model.head.in_features, num_classes)

# Load weight đã train
model.load_state_dict(torch.load("/kaggle/working/swin_tiny_best.pth", map_location=device))
model = model.to(device)
model.eval()

# =====================
# Transform cho ảnh test
# =====================
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # resize giống input khi train
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# =====================
# Predict từ link ảnh
# =====================
def predict_from_url(url, class_names):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content)).convert("RGB")
    img_tensor = transform(img).unsqueeze(0).to(device)  # thêm batch dimension

    with torch.no_grad():
        outputs = model(img_tensor)
        probs = torch.softmax(outputs, dim=1)
        pred_idx = torch.argmax(probs, dim=1).item()
    
    print(f"Predicted class: {class_names[pred_idx]} (prob = {probs[0][pred_idx]:.4f})")
    return class_names[pred_idx]

# =====================
# Ví dụ chạy thử
# =====================
# Lấy tên class từ ImageFolder
class_names = image_datasets['train'].classes  

url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFuI1z0kcbSqY4aipR3sB0NoiGcbfhirWKoc4cSn7hCxP1pdY70jOmFenB74wUD6ZSYFRjzd38FCzkeogaji8JvEjQeiL_4-KeTbKVe1E"
predict_from_url(url, class_names)
# Out:
# Predicted class: Lycodon_chapaensis (prob = 0.6954)
# 'Lycodon_chapaensis'
